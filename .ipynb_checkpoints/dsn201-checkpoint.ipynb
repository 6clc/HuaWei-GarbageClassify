# %%
pip install fastai
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 245kB 1.9MB/s eta 0:00:01
# ...
#      |█▋                              | 37.0MB 3.2MB/s eta 0:03:476

# %%
from fastai.vision import *
import torch.nn as nn
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-bc77327db64c> in <module>
# ----> 1 from fastai.vision import *
#       2 import torch.nn as nn
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'fastai'

# %% [markdown]
# ## 定义数据

# %%
root_dir = '/home/hanshan/Data/DataCV'
df = pd.read_csv('/home/hanshan/Data/DataCV/CSVs/huawei-garbage-classification/info.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e99603758cbf> in <module>
#       1 root_dir = '/home/hanshan/Data/DataCV'
# ----> 2 df = pd.read_csv('/home/hanshan/Data/DataCV/CSVs/huawei-garbage-classification/info.csv')
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %%
pos = 0
means = int(len(df) / 5)
nums = list(range(0, len(df)))

valid_index = nums[pos*means:(pos+1)*means]
train_index = nums[0:pos*means] + nums[(pos+1)*means:]
len(valid_index), len(train_index)
# Out:
# (2936, 11747)

# %%
df = df.iloc[:, [0, 1]]

# %%
tfms = get_transforms(do_flip=False, 
                  flip_vert=True, 
                  max_rotate=10, 
                  max_zoom=1, 
                  max_lighting=None, 
                  max_warp=None, 
                  p_affine=0.75, 
                  p_lighting=None)
tfms[0]
# Out:
# [RandTransform(tfm=TfmCrop (crop_pad), kwargs={'row_pct': (0, 1), 'col_pct': (0, 1), 'padding_mode': 'reflection'}, p=1.0, resolved={}, do_run=True, is_random=True, use_on_y=True),
#  RandTransform(tfm=TfmAffine (rotate), kwargs={'degrees': (-10, 10)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True)]

# %%
data = (ImageList.from_df(df=df, path=root_dir)
        .split_by_idxs(train_idx=train_index, valid_idx=valid_index)
        .label_from_df()
        .transform(size=256, resize_method=ResizeMethod.SQUISH)
        .databunch(bs=32)
        .normalize(imagenet_stats))

# %% [markdown]
# ## 定义模型

# %%
from torch import nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, logits=False, reduction='elementwise_mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduction = reduction

    def forward(self, inputs, targets):
        if self.logits:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        else:
            BCE_loss = F.binary_cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduction is None:
            return F_loss
        else:
            return torch.mean(F_loss)

# %%
learn = cnn_learner(data,models.densenet201, pretrained=True, metrics=[accuracy, error_rate],
                    callback_fns=[ShowGraph])
learn.loss_fn = FocalLoss()

# %%
len(learn.layer_groups)
# Out:
# 3

# %%
path = Path('/home/he/Projects/fastai/dsn201')
if not os.path.exists(path):
    os.makedirs(path)

# %%
path

# %% [markdown]
# ## first stage

# %%
learn.freeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)

# %%
lr = 3e-3

# %%
learn.fit_one_cycle(5, slice(lr))

# %%
learn.save(path/'stage-1')

# %% [markdown]
# ## two stage

# %% [markdown]
# ### way1

# %%
learn.load(path/'stage-1')
learn.freeze_to(1)
learn.lr_find()
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))

# %%
learn.load(path/'stage-1')
learn.freeze_to(1)
learn.fit_one_cycle(5, slice(1e-5, lr/5), wd=1e-3)

# %%
learn.save(path/'stage2')

# %% [markdown]
# ## three stage

# %%
data = (ImageList.from_df(df=df, path=root_dir)
        .split_by_idxs(train_idx=train_index, valid_idx=valid_index)
        .label_from_df()
        .transform(get_transforms(), size=256, resize_method=ResizeMethod.SQUISH)
        .databunch(bs=32)
        .normalize(imagenet_stats))

# %%
learn.load(path/'stage2')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (11747 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# 39,0,0,0,0
# Path: /home/he/Data;
#
# Valid: LabelList (2936 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# 0,0,0,0,0
# Path: /home/he/Data;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
# ...

# %%
preds, target = learn.TTA()

# %%
accuracy(preds, target)
# Out:
# tensor(0.9278)

# %%
learn.data=data
learn.freeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.91E-06
# Min loss divided by 10: 8.32E-07

# %%
learn.fit_one_cycle(5, slice(3e-3), wd=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>epoch</td>
#       <td>train_loss</td>
#       <td>valid_loss</td>
#       <td>accuracy</td>
#       <td>error_rate</td>
#       <td>time</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>0.162794</td>
#       <td>0.370017</td>
#       <td>0.905995</td>
#       <td>0.094005</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>0.162794</td>
#       <td>0.370017</td>
#       <td>0.905995</td>
#       <td>0.094005</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.246282</td>
#       <td>0.416950</td>
#       <td>0.903951</td>
#       <td>0.096049</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
# ...

# %%
preds, target = learn.TTA()

# %%
accuracy(preds, target)
# Out:
# tensor(0.9275)
